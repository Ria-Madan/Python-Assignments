# %% [markdown]
# <a href="https://colab.research.google.com/github/Ria-Madan/Python-Assignments/blob/main/Subset_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# Find all the subsets from a set of numbers whose sum is zero.
# Constraint: Subset size must be 5
# Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}
#
# ---

# %%
import random as r
Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}

SS=set()

for j in range(3,7):
  for i in range(100000):
    s=r.sample(Set,j)
    s.sort()
    if(sum(s)==0):
      SS.add(tuple(s))
  print(j,"-->",len(SS))
  print(SS)
# Out:
# <ipython-input-22-2376bf5c32c5>:8: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   s=r.sample(Set,j)
# 3 --> 20
# {(-9, 2, 7), (-5, 2, 3), (-12, 3, 9), (-4, 1, 3), (-7, -2, 9), (-12, 1, 11), (-8, 1, 7), (-8, 2, 6), (-7, -4, 11), (-9, -2, 11), (-6, -3, 9), (-4, -2, 6), (-5, -2, 7), (-6, -5, 11), (-3, 1, 2), (-7, 1, 6), (-4, -3, 7), (-9, 3, 6), (-8, -3, 11), (-5, -4, 9)}
# 4 --> 74
# ...

# %%
import random as r
Set={-12, -3, -6, 7, 2, -2, 6, 3, 9, -7, -5, -8, 1, 11, -9, -4}

SS=set()

for i in range(100000):
  s=r.sample(Set,5)
  s.sort()
  if(sum(s)==0):
    SS.add(tuple(s))
    

print(SS,"\n")
print(len(SS))
# Out:
# <ipython-input-18-b1ec379ea6fd>:7: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   s=r.sample(Set,5)
# ...
